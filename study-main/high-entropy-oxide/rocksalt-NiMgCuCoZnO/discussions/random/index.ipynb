# %% [markdown]
# 必要なライブラリのインポート

# %%
import matplotlib.pyplot as plt
import pandas as pd
import GPy
from GPy import kern as gp_kern
import numpy as np
from scipy.stats import norm
from sklearn.metrics import r2_score
import time

# %%
OUTPUT_LOG = True
NUM_CANDIDATES = 20

# %%
def debug_print(*args):
    if OUTPUT_LOG:
        print(*args)

# %% [markdown]
# データの読み込み

# %%
# データの読み込み
df = pd.read_csv(
    "data.csv",
    engine="python",
    encoding="utf-8",
)

# IDをインデックスに設定
df = df.set_index("ID")
debug_print(df)

# 重複行の確認（全データセットに対して）
duplicates = df[df.duplicated(keep=False)]
debug_print(duplicates)

# 'energy'列にデータがある行のみを抽出
df_with_energy = df.dropna(subset=["energy"])
debug_print(df_with_energy)

# 'energy'列にデータがない行のみを抽出
df_without_energy = df[df["energy"].isnull()].drop(columns=["energy"])
debug_print(df_without_energy)

min_index = df["energy"].idxmin()
min_value = min(df["energy"])
debug_print(min_index, min_value)
# Out:
#          Ni  Ni_Mg  Cu_Ni  Co_Ni  Zn_Ni  Mg  Cu_Mg  Co_Mg  Zn_Mg  Cu  Co_Cu  \
# ID
# 1         5     13     13     18     18   7     15     14     16   5     16
# 2         9     11     16     11     16   7     15     17     15   5     18
# 3         4     14     14     18     18   6     18     17     11   7     13
# 4         5     13     14     16     19   6     16     17     14   4     11
# 5         5     20     14     16     12   4     11     17     16   6     17
# ...      ..    ...    ...    ...    ...  ..    ...    ...    ...  ..    ...
# 999996    5     12     14     16     20   7     18     11     17   3     17
# 999997    4     15     14     19     16   5     10     15     22   8     17
# 999998    8     14     16     12     14   5     15     18     15   6     13
# 999999    5     13     18     17     14   4     13     14     24   7     12
# 1000000   6     18     14     18     10   6     12     16     14   6     15
#
#          Zn_Cu  Co  Zn_Co  Zn      energy
# ID
# 1           18   6     24   4 -335.563032
# 2           13   7     24   8 -335.926384
# 3           13   5     26   8 -335.874215
# 4           23  12     16   6 -335.812556
# 5           18   7     20   9 -335.898355
# ...        ...  ..    ...  ..         ...
# 999996      17  10     20   5         NaN
# 999997      15   8     17   7         NaN
# 999998      16   9     23   8         NaN
# 999999      15  11     19   6         NaN
# 1000000     19  10     15  13         NaN
#
# [1000000 rows x 16 columns]
# Empty DataFrame
# Columns: [Ni, Ni_Mg, Cu_Ni, Co_Ni, Zn_Ni, Mg, Cu_Mg, Co_Mg, Zn_Mg, Cu, Co_Cu, Zn_Cu, Co, Zn_Co, Zn, energy]
# Index: []
#         Ni  Ni_Mg  Cu_Ni  Co_Ni  Zn_Ni  Mg  Cu_Mg  Co_Mg  Zn_Mg  Cu  Co_Cu  \
# ID
# 1        5     13     13     18     18   7     15     14     16   5     16
# 2        9     11     16     11     16   7     15     17     15   5     18
# 3        4     14     14     18     18   6     18     17     11   7     13
# 4        5     13     14     16     19   6     16     17     14   4     11
# 5        5     20     14     16     12   4     11     17     16   6     17
# ...     ..    ...    ...    ...    ...  ..    ...    ...    ...  ..    ...
# 987093   4     11     18     18     17   6     16     13     20   4     17
# 987226   5     14     12     19     17   3     19     17     16   5     13
# 990226   6     17     10     19     14   6     15     12     16   6     17
# 997835   7     10     14     19     15   7     12     19     17   9     13
# 998736   3     11     14     23     18   5     14     15     22   5     15
#
#         Zn_Cu  Co  Zn_Co  Zn      energy
# ID
# 1          18   6     24   4 -335.563032
# 2          13   7     24   8 -335.926384
# 3          13   5     26   8 -335.874215
# 4          23  12     16   6 -335.812556
# 5          18   7     20   9 -335.898355
# ...       ...  ..    ...  ..         ...
# 987093     13   8     20   7 -336.066441
# 987226     18   7     21   6 -335.867750
# 990226     18   8     20   8 -335.783469
# 997835     15   8     17  10 -335.813154
# 998736     19   6     19   3 -335.691290
#
# [300 rows x 16 columns]
#          Ni  Ni_Mg  Cu_Ni  Co_Ni  Zn_Ni  Mg  Cu_Mg  Co_Mg  Zn_Mg  Cu  Co_Cu  \
# ID
# 101       8     15     10     18     13   5     18     17     12   8     11
# 102       5     16     11     14     21   2     19     18     15   9     14
# 103       5     12     13     21     16   5     13     18     19   7     18
# 104       5     17      8     18     19   5     16     16     13   6     19
# 105       7     12     14     15     17   7     13     15     18   6     16
# ...      ..    ...    ...    ...    ...  ..    ...    ...    ...  ..    ...
# 999996    5     12     14     16     20   7     18     11     17   3     17
# 999997    4     15     14     19     16   5     10     15     22   8     17
# 999998    8     14     16     12     14   5     15     18     15   6     13
# 999999    5     13     18     17     14   4     13     14     24   7     12
# 1000000   6     18     14     18     10   6     12     16     14   6     15
#
#          Zn_Cu  Co  Zn_Co  Zn
# ID
# 101         17   8     22  10
# 102         10   8     22   8
# 103         14   6     15  10
# 104         17   9     13  11
# 105         17   9     20   6
# ...        ...  ..    ...  ..
# 999996      17  10     20   5
# 999997      15   8     17   7
# 999998      16   9     23   8
# 999999      15  11     19   6
# 1000000     19  10     15  13
#
# [999700 rows x 15 columns]
# 986800 -336.401979

# %% [markdown]
# ガウス過程回帰の処理

# %%
# 特徴量とターゲット変数の分割
X = df_with_energy.iloc[:, :-1]
y = df_with_energy.iloc[:, -1:]

# ガウス過程回帰モデルの設定と訓練
num = X.shape[1]
kernel = gp_kern.RBF(num) * gp_kern.Bias(num) + gp_kern.Linear(num) * gp_kern.Bias(num)
model = GPy.models.GPRegression(X.values, y.values, kernel=kernel, normalizer=True)
model.optimize()

# %% [markdown]
# データの y と予測された y'の比較

# %%
pred_y, _ = model.predict(X.values)
if OUTPUT_LOG:
    fig_vs = plt.figure(figsize=(4, 4))
    plt.scatter(y.values.flatten(), pred_y.flatten())
    plt.plot([min(y.values), max(y.values)], [min(y.values), max(y.values)], ls="--")
    plt.xlabel("calc /eV")
    plt.ylabel("predict /eV")
    plt.show()

# %%
# 相関係数と決定係数の計算
correlation_coefficient = np.corrcoef(y.values.flatten(), pred_y.flatten())[0, 1]
r2 = r2_score(y.values, pred_y)

debug_print(f"相関係数: {correlation_coefficient:.3f}")
debug_print(f"決定係数 (R²): {r2:.3f}")
# Out:
# 相関係数: 1.000
# 決定係数 (R²): 1.000

# %% [markdown]
# ガウス過程回帰の結果のプロット(1 次元プロット)

# %%
# save_dir = "./images/"
# print(X.loc[min_index,:])
if OUTPUT_LOG:
    for i in range(len(X.columns)):
        vis_dim = [(vis1, vis2) for vis1, vis2 in enumerate(X.loc[min_index, :])]

        debug_print(vis_dim)

        view_variable = i
        vis_dim.pop(view_variable)
        debug_print(X.columns[view_variable])
        # vis_dim[0] =(0,0)
        # vis_dim[1] =(1,1)
        # Optimize後
        fig = plt.figure(figsize=(6, 4))
        # fig.suptitle(X.columns[i])

        ax = fig.add_subplot(111)
        ax.set_xlabel(X.columns[i])
        model.plot(fixed_inputs=vis_dim, plot_density=False, ax=ax)
        # if save_dir != None:
        #     plt.savefig(os.path.join(save_dir,
        #                 ""+X.columns[i]+"_.png"))
        # plt.ylim(-4,0)
        plt.show()
        plt.clf()
# Out:
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Ni
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Ni_Mg
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Cu_Ni
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Co_Ni
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Zn_Ni
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Mg
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Cu_Mg
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Co_Mg
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Zn_Mg
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Cu
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Co_Cu
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Zn_Cu
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Co
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Zn_Co
# [(0, 8), (1, 11), (2, 14), (3, 18), (4, 13), (5, 4), (6, 14), (7, 22), (8, 17), (9, 4), (10, 13), (11, 23), (12, 7), (13, 17), (14, 7)]
# Zn

# %% [markdown]
# ---

# %% [markdown]
# ガウス過程回帰の結果のプロット(2 次元プロット)

# %%
# # gd = [40,45,50,55,60]
# # eu = [2,4,6,8,10]
# # sm = [2,4,6,8,10]
# Zn = [2,4,6,8,10]


# for i in Zn:
#     fig = plt.figure(figsize=(6, 4))
#     fig.suptitle(X.columns[0]+ str(i))
#     ax = fig.add_subplot(111)
#     ax.set_xlabel(X.columns[1])
#     ax.set_ylabel(X.columns[2])

#     # ax.contour( cmap="jet", levels=10, alpha=1)
#     model.plot(
#                 fixed_inputs=[(0, i)],
#                 plot_data=False,
#                 ax=ax,
#                 color=plt.get_cmap('jet')
#                 )

# %% [markdown]
# ベイズ最適化

# %% [markdown]
# 獲得関数

# %%
# 獲得関数
def acquisition_lcb(mean, std, kappa):
    a = mean - kappa * std
    return a


def acquisition_EI(mean, std, min_value, xi=0.001):
    imp = min_value - mean - xi
    Z = imp / std
    ei = imp * norm.cdf(Z) + std * norm.pdf(Z)
    return ei

# %% [markdown]
# 予測する特徴量の範囲を指定

# %%
progress_count = 0
progress_level = 0
total_iterations = df.shape[0] - df_with_energy.shape[0]
progress_interval = total_iterations // 50 + 1

debug_print(total_iterations)

start_time = time.time()


def display_progress():
    global progress_count
    global progress_level
    progress_count += 1

    current_level = progress_count // progress_interval

    if not (current_level > progress_level or progress_count == total_iterations):
        return

    progress_level = current_level
    elapsed_time = time.time() - start_time
    debug_print(
        f"Progress: {progress_count}/{total_iterations} ({progress_count/total_iterations*100:.2f}%), Elapsed time: {elapsed_time:.2f}s"
    )

    debug_print(f"progress_count: {progress_count}, progress_level: {progress_level}")
# Out:
# 999700

# %% [markdown]
# 各特徴量での獲得関数の計算

# %%
means = []
stds = []
acs_ei = []
acs_lcb = []

itera = df_without_energy.values

debug_print(itera)

for item in itera:
    display_progress()

    # 期待値と分散
    mean, val = model.predict(np.array(item).reshape(1, -1))
    # 標準偏差
    std = np.sqrt(val)

    # 獲得関数(EI)
    ac_ei = acquisition_EI(mean, std, min_value)
    # 獲得関数(LCB)
    ac_lcb = acquisition_lcb(mean, std, 7)

    # それぞれをリストにまとめる
    means.append(mean.flatten()[0])
    stds.append(std.flatten()[0])
    acs_ei.append(ac_ei.flatten()[0])
    acs_lcb.append(ac_lcb.flatten()[0])
# Out:
# [[ 8 15 10 ...  8 22 10]
#  [ 5 16 11 ...  8 22  8]
#  [ 5 12 13 ...  6 15 10]
#  ...
#  [ 8 14 16 ...  9 23  8]
#  [ 5 13 18 ... 11 19  6]
#  [ 6 18 14 ... 10 15 13]]
# Progress: 19995/999700 (2.00%), Elapsed time: 7.72s
# progress_count: 19995, progress_level: 1
# Progress: 39990/999700 (4.00%), Elapsed time: 15.14s
# progress_count: 39990, progress_level: 2
# Progress: 59985/999700 (6.00%), Elapsed time: 23.27s
# progress_count: 59985, progress_level: 3
# Progress: 79980/999700 (8.00%), Elapsed time: 30.80s
# progress_count: 79980, progress_level: 4
# Progress: 99975/999700 (10.00%), Elapsed time: 38.32s
# progress_count: 99975, progress_level: 5
# Progress: 119970/999700 (12.00%), Elapsed time: 45.91s
# progress_count: 119970, progress_level: 6
# Progress: 139965/999700 (14.00%), Elapsed time: 53.78s
# progress_count: 139965, progress_level: 7
# Progress: 159960/999700 (16.00%), Elapsed time: 61.54s
# progress_count: 159960, progress_level: 8
# Progress: 179955/999700 (18.00%), Elapsed time: 69.04s
# progress_count: 179955, progress_level: 9
# Progress: 199950/999700 (20.00%), Elapsed time: 76.65s
# progress_count: 199950, progress_level: 10
# Progress: 219945/999700 (22.00%), Elapsed time: 84.08s
# progress_count: 219945, progress_level: 11
# Progress: 239940/999700 (24.00%), Elapsed time: 91.68s
# progress_count: 239940, progress_level: 12
# Progress: 259935/999700 (26.00%), Elapsed time: 99.34s
# progress_count: 259935, progress_level: 13
# Progress: 279930/999700 (28.00%), Elapsed time: 107.11s
# progress_count: 279930, progress_level: 14
# Progress: 299925/999700 (30.00%), Elapsed time: 115.26s
# progress_count: 299925, progress_level: 15
# Progress: 319920/999700 (32.00%), Elapsed time: 122.75s
# progress_count: 319920, progress_level: 16
# Progress: 339915/999700 (34.00%), Elapsed time: 130.20s
# progress_count: 339915, progress_level: 17
# Progress: 359910/999700 (36.00%), Elapsed time: 137.98s
# progress_count: 359910, progress_level: 18
# Progress: 379905/999700 (38.00%), Elapsed time: 145.54s
# progress_count: 379905, progress_level: 19
# Progress: 399900/999700 (40.00%), Elapsed time: 152.99s
# progress_count: 399900, progress_level: 20
# Progress: 419895/999700 (42.00%), Elapsed time: 160.39s
# progress_count: 419895, progress_level: 21
# Progress: 439890/999700 (44.00%), Elapsed time: 167.81s
# progress_count: 439890, progress_level: 22
# Progress: 459885/999700 (46.00%), Elapsed time: 175.26s
# progress_count: 459885, progress_level: 23
# Progress: 479880/999700 (48.00%), Elapsed time: 182.68s
# progress_count: 479880, progress_level: 24
# Progress: 499875/999700 (50.00%), Elapsed time: 190.13s
# progress_count: 499875, progress_level: 25
# Progress: 519870/999700 (52.00%), Elapsed time: 197.72s
# progress_count: 519870, progress_level: 26
# Progress: 539865/999700 (54.00%), Elapsed time: 205.26s
# progress_count: 539865, progress_level: 27
# Progress: 559860/999700 (56.00%), Elapsed time: 212.98s
# progress_count: 559860, progress_level: 28
# Progress: 579855/999700 (58.00%), Elapsed time: 220.67s
# progress_count: 579855, progress_level: 29
# Progress: 599850/999700 (60.00%), Elapsed time: 228.40s
# progress_count: 599850, progress_level: 30
# Progress: 619845/999700 (62.00%), Elapsed time: 235.99s
# progress_count: 619845, progress_level: 31
# Progress: 639840/999700 (64.00%), Elapsed time: 243.61s
# progress_count: 639840, progress_level: 32
# Progress: 659835/999700 (66.00%), Elapsed time: 251.12s
# progress_count: 659835, progress_level: 33
# Progress: 679830/999700 (68.00%), Elapsed time: 259.17s
# progress_count: 679830, progress_level: 34
# Progress: 699825/999700 (70.00%), Elapsed time: 267.09s
# progress_count: 699825, progress_level: 35
# Progress: 719820/999700 (72.00%), Elapsed time: 274.50s
# progress_count: 719820, progress_level: 36
# Progress: 739815/999700 (74.00%), Elapsed time: 282.31s
# progress_count: 739815, progress_level: 37
# Progress: 759810/999700 (76.00%), Elapsed time: 289.89s
# progress_count: 759810, progress_level: 38
# Progress: 779805/999700 (78.00%), Elapsed time: 297.69s
# progress_count: 779805, progress_level: 39
# Progress: 799800/999700 (80.00%), Elapsed time: 305.37s
# progress_count: 799800, progress_level: 40
# Progress: 819795/999700 (82.00%), Elapsed time: 313.05s
# progress_count: 819795, progress_level: 41
# Progress: 839790/999700 (84.00%), Elapsed time: 320.57s
# progress_count: 839790, progress_level: 42
# Progress: 859785/999700 (86.00%), Elapsed time: 328.27s
# progress_count: 859785, progress_level: 43
# Progress: 879780/999700 (88.00%), Elapsed time: 336.00s
# progress_count: 879780, progress_level: 44
# Progress: 899775/999700 (90.00%), Elapsed time: 343.47s
# progress_count: 899775, progress_level: 45
# Progress: 919770/999700 (92.00%), Elapsed time: 350.74s
# progress_count: 919770, progress_level: 46
# Progress: 939765/999700 (94.00%), Elapsed time: 358.04s
# progress_count: 939765, progress_level: 47
# Progress: 959760/999700 (96.00%), Elapsed time: 365.25s
# progress_count: 959760, progress_level: 48
# Progress: 979755/999700 (98.00%), Elapsed time: 372.67s
# progress_count: 979755, progress_level: 49
# Progress: 999700/999700 (100.00%), Elapsed time: 379.80s
# progress_count: 999700, progress_level: 49

# %% [markdown]
# 提案された特徴量を Pandas データフレームとして出力

# %%
result_df = pd.DataFrame(df_without_energy)
result_df = result_df.assign(mean=means, std=stds, EI=acs_ei, LCB=acs_lcb)

# %%
# LCBが最小の行を取得
result_df_sort = result_df.sort_values("LCB", ascending=True)
min_lcb_id = result_df_sort.index[0]

debug_print("ID with the minimum LCB value:", min_lcb_id)
# Out:
# ID with the minimum LCB value: 125833

# %% [markdown]
# EI を降順にプロット

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

result_df_sort = result_df.sort_values("EI", ascending=False)
# 上位20個を表示
result_df_sort[:20]
# 下位20個を表示
# result_df_sort[-20:]
# Out:
#         Ni  Ni_Mg  Cu_Ni  Co_Ni  Zn_Ni  Mg  Cu_Mg  Co_Mg  Zn_Mg  Cu  Co_Cu  \
# ID
# 343051   7     11     15     18     14   3     15     22     18   4     13
# 596910   7     11     15     19     13   4     16     21     16   2     14
# 777826   6     14     13     18     15   6     11     16     19   4     24
# 749890   8      9     15     20     12   5     13     22     18   4     13
# 154931   7     13     13     16     16   7     11     16     18   4     24
# 377049   8     12     14     17     13   4     14     20     18   4     14
# 302625   5     12     15     18     17   3     18     17     19   4     16
# 532131   6     14     12     17     17   6     12     16     18   4     23
# 963013   4     15     16     20     13   5     11     16     20   4     19
# 891387   8     14     10     16     16   4     19     17     14   4     22
# 564334   8     12     15     16     13   4     14     21     17   4     13
# 914763   8     11     14     17     14   4     15     22     16   4     14
# 378138   5     12     15     18     17   4     17     16     19   4     18
# 238812   6     15     14     16     15   6     11     16     18   4     23
# 866741   5     13     14     17     18   7     12     16     17   3     23
# 902171   8     11     13     19     13   4     16     21     16   4     13
# 265295   6     12     14     17     17   3     18     17     19   4     16
# 796663   5     12     16     17     17   4     16     16     20   4     16
# 242096   6     14     15     16     15   6     12     15     19   3     23
# 524564   5     12     16     18     16   3     19     17     18   3     15
#
#         Zn_Cu  Co  Zn_Co  Zn        mean       std        EI         LCB
# ID
# 343051     21   7     17   7 -336.193547  0.115982  0.001632 -337.005419
# 596910     23   7     16   8 -336.142132  0.132190  0.001205 -337.067458
# 777826     16   5     16   9 -336.190755  0.110052  0.001130 -336.961122
# 749890     23   6     17   7 -336.145633  0.129305  0.001127 -337.050768
# 154931     16   6     16   9 -336.194842  0.108216  0.001126 -336.952352
# 377049     22   8     17   7 -336.174098  0.115767  0.001045 -336.984470
# 302625     15   8     17   8 -336.160135  0.120050  0.000959 -337.000486
# 532131     17   6     16   8 -336.170276  0.112239  0.000781 -336.955949
# 963013     18   5     19   7 -336.159555  0.115305  0.000723 -336.966692
# 891387     13   5     19  11 -336.127264  0.126818  0.000667 -337.014993
# 564334     22   8     18   7 -336.158490  0.114183  0.000659 -336.957768
# 914763     21   7     17   8 -336.158504  0.113921  0.000648 -336.955953
# 378138     14   7     18   8 -336.128920  0.125541  0.000644 -337.007709
# 238812     16   6     17   9 -336.142828  0.119884  0.000638 -336.982013
# 866741     17   6     16   8 -336.139226  0.120958  0.000625 -336.985931
# 902171     22   6     19   7 -336.120036  0.127565  0.000592 -337.012992
# 265295     16   9     16   8 -336.152978  0.114192  0.000575 -336.952322
# 796663     16   9     17   7 -336.173324  0.105785  0.000561 -336.913816
# 242096     16   6     18   8 -336.111622  0.129728  0.000556 -337.019721
# 524564     16   8     18   8 -336.105807  0.131551  0.000543 -337.026666

# %% [markdown]
# LCB を昇順にプロット

# %%
result_df_sort = result_df.sort_values("LCB", ascending=True)
# 上位20個を表示
result_df_sort[:20]
# 下位20個を表示
# result_df_sort[-20:]
# Out:
#         Ni  Ni_Mg  Cu_Ni  Co_Ni  Zn_Ni  Mg  Cu_Mg  Co_Mg  Zn_Mg  Cu  Co_Cu  \
# ID
# 125833   9     10     22     15      7   5     10     18     24   3     21
# 279694   8     12     23     13      8   3     14     20     20   2     17
# 596910   7     11     15     19     13   4     16     21     16   2     14
# 887792  10     17     16     13      6   1     16     18     19   2     21
# 749890   8      9     15     20     12   5     13     22     18   4     13
# 103074   5     13     17     19     13   5     11     17     21   2     21
# 240248   5     13     19     17     13   4     13     19     19   0     22
# 677891   7      8     20     23      7   5     15     17     22   3     17
# 419439   7     13     18     16     11   5     15     19     15   0     23
# 392246   4     14     20     16     14   4     14     21     15   1     22
# 950443   6     13     18     14     15   2     16     20     19   0     20
# 857998   8      9     20     15     12   3     15     19     23   2     19
# 977010   8      9     17     15     15   2     17     20     22   2     20
# 496973   4     12     21     15     16   4     14     15     23   1     24
# 705821   4     12     25     16     11   3     14     14     26   3     16
# 182263   6     13     14     18     15   6     11     17     19   3     22
# 576755   6      7     22     17     14   4     17     20     20   2     16
# 761854   7     10     19     11     18   4     18     18     18   0     22
# 526111   8     10     21     14     11   5     11     25     16   3     17
# 785843   6     14     16     16     14   6     10     15     21   2     25
#
#         Zn_Cu  Co  Zn_Co  Zn        mean       std        EI         LCB
# ID
# 125833     13   5     20  10 -336.002221  0.153549  0.000218 -337.077063
# 279694     14   7     20  11 -336.005079  0.152303  0.000214 -337.071202
# 596910     23   7     16   8 -336.142132  0.132190  0.001205 -337.067458
# 887792     15   7     18  13 -335.986418  0.153105  0.000152 -337.058153
# 749890     23   6     17   7 -336.145633  0.129305  0.001127 -337.050768
# 103074     19   4     19   6 -336.054579  0.142311  0.000335 -337.050758
# 240248     18   4     18   8 -336.004283  0.149461  0.000176 -337.050507
# 677891     14   4     19  11 -335.979488  0.152906  0.000129 -337.049831
# 419439     16   4     18  12 -335.995302  0.150603  0.000156 -337.049522
# 392246     14   2     21  10 -335.992032  0.150939  0.000149 -337.048607
# 950443     18   5     20   6 -336.004207  0.149065  0.000171 -337.047661
# 857998     14   6     19   8 -335.998549  0.149756  0.000158 -337.046838
# 977010     14   6     17   8 -335.997711  0.149573  0.000154 -337.044720
# 496973     11   7     16   9 -335.985918  0.151233  0.000133 -337.044547
# 705821     11   9     20   8 -335.965377  0.154166  0.000103 -337.044540
# 182263     19   5     17   7 -336.088875  0.136436  0.000496 -337.043924
# 576755     13   8     15  11 -335.983815  0.151378  0.000128 -337.043459
# 761854     13   8     17   9 -335.988621  0.150485  0.000134 -337.042014
# 526111     17   3     22   9 -335.980627  0.151616  0.000121 -337.041937
# 785843     17   6     16   8 -336.048609  0.141876  0.000286 -337.041743

# %%
result_df_sort = result_df.sort_values("mean", ascending=True)
result_df_sort[:20]
# result_df_sort[-20:]
# Out:
#         Ni  Ni_Mg  Cu_Ni  Co_Ni  Zn_Ni  Mg  Cu_Mg  Co_Mg  Zn_Mg  Cu  Co_Cu  \
# ID
# 154931   7     13     13     16     16   7     11     16     18   4     24
# 343051   7     11     15     18     14   3     15     22     18   4     13
# 127251   5     11     16     17     18   5     17     16     18   4     16
# 777826   6     14     13     18     15   6     11     16     19   4     24
# 178479   5     11     15     19     17   5     17     16     18   4     16
# 818737   5     15     14     20     13   5     10     16     21   5     18
# 377049   8     12     14     17     13   4     14     20     18   4     14
# 796663   5     12     16     17     17   4     16     16     20   4     16
# 532131   6     14     12     17     17   6     12     16     18   4     23
# 302625   5     12     15     18     17   3     18     17     19   4     16
# 963013   4     15     16     20     13   5     11     16     20   4     19
# 914763   8     11     14     17     14   4     15     22     16   4     14
# 564334   8     12     15     16     13   4     14     21     17   4     13
# 317984   6     11     16     17     16   4     17     18     18   4     15
# 65846    6     12     14     17     17   4     18     16     18   4     17
# 265295   6     12     14     17     17   3     18     17     19   4     16
# 675012   6     13     14     17     16   8      9     14     20   4     24
# 257161   6     11     15     18     16   5     17     16     18   5     15
# 749890   8      9     15     20     12   5     13     22     18   4     13
# 35347    5     12     16     17     17   4     17     17     18   3     16
#
#         Zn_Cu  Co  Zn_Co  Zn        mean       std        EI         LCB
# ID
# 154931     16   6     16   9 -336.194842  0.108216  0.001126 -336.952352
# 343051     21   7     17   7 -336.193547  0.115982  0.001632 -337.005419
# 127251     15   9     17   8 -336.192348  0.079938  0.000105 -336.751913
# 777826     16   5     16   9 -336.190755  0.110052  0.001130 -336.961122
# 178479     16   8     17   8 -336.182479  0.094651  0.000318 -336.845034
# 818737     20   6     18   6 -336.174528  0.094531  0.000245 -336.836244
# 377049     22   8     17   7 -336.174098  0.115767  0.001045 -336.984470
# 796663     16   9     17   7 -336.173324  0.105785  0.000561 -336.913816
# 532131     17   6     16   8 -336.170276  0.112239  0.000781 -336.955949
# 302625     15   8     17   8 -336.160135  0.120050  0.000959 -337.000486
# 963013     18   5     19   7 -336.159555  0.115305  0.000723 -336.966692
# 914763     21   7     17   8 -336.158504  0.113921  0.000648 -336.955953
# 564334     22   8     18   7 -336.158490  0.114183  0.000659 -336.957768
# 317984     16   8     18   8 -336.157278  0.100020  0.000229 -336.857418
# 65846      15   9     16   9 -336.153975  0.103360  0.000274 -336.877492
# 265295     16   9     16   8 -336.152978  0.114192  0.000575 -336.952322
# 675012     17   6     17   7 -336.149644  0.110514  0.000414 -336.923243
# 257161     15   9     17   9 -336.146626  0.090595  0.000062 -336.780794
# 749890     23   6     17   7 -336.145633  0.129305  0.001127 -337.050768
# 35347      17   9     16   8 -336.144709  0.102557  0.000194 -336.862607

# %% [markdown]
# 候補 3 つの ID を出力

# %%
result_df_sort = result_df.sort_values("LCB", ascending=True)
debug_print(result_df_sort.head(NUM_CANDIDATES).index.tolist())
# Out:
# [125833, 279694, 596910, 887792, 749890, 103074, 240248, 677891, 419439, 392246, 950443, 857998, 977010, 496973, 705821, 182263, 576755, 761854, 526111, 785843]
